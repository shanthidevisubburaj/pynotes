# %%
with open("test.txt", "w") as f:
    f.write("Hello File!")

# %%
with open("test.txt", "r") as f:
    print(f.read())
# Out:
# Hello File!

# %%
class Student:
    def __init__(self, name):
        self.name = name

s = Student("Alice")
print("Student name:", s.name)
# Out:
# Student name: Alice
