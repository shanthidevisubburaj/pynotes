# %%
numbers = [10, 25, 7, 50, 32]
print("Largest:", max(numbers))
# Out:
# Largest: 50

# %%
num = 6
print("Square:", num ** 2)
# Out:
# Square: 36

# %%
a, b = 10, 20
a, b = b, a
print("a =", a, "b =", b)
# Out:
# a = 20 b = 10
