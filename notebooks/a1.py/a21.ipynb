# %%
nums=[1,2,3,4]
squares=list(map(lambda x:x**2,nums))
print(squares)
# Out:
# [1, 4, 9, 16]

# %%
nums = [10, 15, 20, 25, 30]
evens = list(filter(lambda x: x % 2 == 0, nums))
print(evens)
# Out:
# [10, 20, 30]

# %%
square = lambda x: x**2
print("Square of 7:", square(7))
# Out:
# Square of 7: 49
