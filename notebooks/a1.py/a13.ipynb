# %%
nums = [10, 20, 30, 40]
print("Average:", sum(nums)/len(nums))
# Out:
# Average: 25.0

# %%
nums = [1, 2, 2, 3, 4, 4]
print("Unique:", list(set(nums)))
# Out:
# Unique: [1, 2, 3, 4]

# %%
nums = [5, 2, 9, 1]
nums.sort()
print("Sorted:", nums)
# Out:
# Sorted: [1, 2, 5, 9]
