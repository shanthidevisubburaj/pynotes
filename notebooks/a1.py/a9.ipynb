# %%
nums = [1, 2, 3, 4]
print("Reversed:", nums[::-1])
# Out:
# Reversed: [4, 3, 2, 1]

# %%
numbers = [12, 5, 9, 30]
print("Minimum:", min(numbers))
# Out:
# Minimum: 5

# %%
p, r, t = 1000, 5, 2
si = (p * r * t) / 100
print("Simple Interest:", si)
# Out:
# Simple Interest: 100.0
