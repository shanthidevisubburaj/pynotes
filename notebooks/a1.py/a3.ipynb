# %%
def greet():
    print("Welcome to Python!")
greet()
# Out:
# Welcome to Python!

# %%
def add(x, y):
    return x + y

print("Result:", add(10, 20))
# Out:
# Result: 30

# %%
fruits = ["apple", "banana", "cherry"]
for fruit in fruits:
    print(fruit)
# Out:
# apple
# banana
# cherry
