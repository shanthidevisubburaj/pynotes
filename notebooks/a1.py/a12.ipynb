# %%
a, b, c = 15, 25, 10
print("Largest:", max(a, b, c))
# Out:
# Largest: 25

# %%
a, b, c = 15, 25, 10
print("Smallest:", min(a, b, c))
# Out:
# Smallest: 10

# %%
nums = [2, 4, 6, 8]
print("Sum:", sum(nums))
# Out:
# Sum: 20
