# %%
num = int(input("Enter a number: "))
if num % 2 == 0:
    print("Even")
else:
    print("Odd")
# Out:
# Enter a number:  4
# Even

# %%
for i in range(5):
    print("Iteration:", i)
# Out:
# Iteration: 0
# Iteration: 1
# Iteration: 2
# Iteration: 3
# Iteration: 4

# %%
count = 1
while count <= 5:
    print("Count:", count)
    count += 1
# Out:
# Count: 1
# Count: 2
# Count: 3
# Count: 4
# Count: 5
