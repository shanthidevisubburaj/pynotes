# %%
print("5" + "3")
print(int("5") + int("3"))
# Out:
# 53
# 8

# %%
x = [5, 3, 8, 1, 9, 2]
print(sorted(x))
print(sorted(x, reverse=True))
print(x)
# Out:
# [1, 2, 3, 5, 8, 9]
# [9, 8, 5, 3, 2, 1]
# [5, 3, 8, 1, 9, 2]

# %%
def multiply(n):
    return lambda x: x * n

double = multiply(2)
triple = multiply(3)

print(double(5))
print(triple(5))
# Out:
# 10
# 15
