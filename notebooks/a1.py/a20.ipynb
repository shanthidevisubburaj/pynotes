# %%
ch = 'A'
print("ASCII value:", ord(ch))
# Out:
# ASCII value: 65

# %%
num = 66
print("Character:", chr(num))
# Out:
# Character: B

# %%
nums = [10, 20, 30, 40, 50]
print("Slice:", nums[1:4])
# Out:
# Slice: [20, 30, 40]
